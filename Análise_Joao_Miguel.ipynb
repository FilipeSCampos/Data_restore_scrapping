# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/product_prices.csv')
data
# Out:
#             Date                                              Price
# 0     2024-04-29                     R$3.999R$3.134,0521% OFFno Pix
# 1     2024-04-28                     R$3.999R$3.134,0521% OFFno Pix
# 2     2024-04-27                     R$3.999R$3.134,0521% OFFno Pix
# 3     2024-04-26                     R$3.999R$3.134,0521% OFFno Pix
# 4     2024-04-25                     R$3.999R$3.134,0521% OFFno Pix
# ...          ...                                                ...
# 1091  2021-05-04  R$3.999R$3.134,0521% OFFno Pixou R$3.299 em 10...
# 1092  2021-05-03                     R$3.999R$3.134,0521% OFFno Pix
# 1093  2021-05-02                     R$3.999R$3.134,0521% OFFno Pix
# 1094  2021-05-01                     R$3.999R$3.134,0521% OFFno Pix
# 1095  2021-04-30  R$3.999R$3.134,0521% OFFno Pixou R$3.299 em 10...
#
# [1096 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1096 non-null   object
#  1   Price   1095 non-null   object
# dtypes: object(2)
# memory usage: 17.2+ KB

# %%
# Criar DataFrame
df = pd.DataFrame(data)

# Extrair preços
df['Price_1'] = df['Price'].str.extract(r'R\$(\d+\.?\d*)')[0]
df['Price_2'] = df['Price'].str.extract(r'em (\d+\.?\d*)')[0]

# Exibir DataFrame resultante
print(df)
# Out:
#             Date  Price Price_1 Price_2
# 0     2024-04-29  3.999     NaN     NaN
# 1     2024-04-28  3.999     NaN     NaN
# 2     2024-04-27  3.999     NaN     NaN
# 3     2024-04-26  3.999     NaN     NaN
# 4     2024-04-25  3.999     NaN     NaN
# ...          ...    ...     ...     ...
# 1091  2021-05-04  3.999     NaN     NaN
# 1092  2021-05-03  3.999     NaN     NaN
# 1093  2021-05-02  3.999     NaN     NaN
# 1094  2021-05-01  3.999     NaN     NaN
# 1095  2021-04-30  3.999     NaN     NaN
#
# [1096 rows x 4 columns]

# %%
# Remover as colunas 'Price_1' e 'Price_2'
df.drop(columns=['Price_1', 'Price_2'], inplace=True)

# %%
# Remover todos os valores NaN do DataFrame
df = df.dropna()

# %%
df
# Out:
#             Date  Price
# 0     2024-04-29  3.999
# 1     2024-04-28  3.999
# 2     2024-04-27  3.999
# 3     2024-04-26  3.999
# 4     2024-04-25  3.999
# ...          ...    ...
# 1091  2021-05-04  3.999
# 1092  2021-05-03  3.999
# 1093  2021-05-02  3.999
# 1094  2021-05-01  3.999
# 1095  2021-04-30  3.999
#
# [1095 rows x 2 columns]

# %%
# Converter a coluna 'Date' para o tipo datetime
df['Date'] = pd.to_datetime(df['Date'])

# Converter a coluna 'Price' para o tipo float
df['Price'] = df['Price'].astype(float)

# Exibir o DataFrame resultante
print(df)
# Out:
#            Date  Price
# 0    2024-04-29  3.999
# 1    2024-04-28  3.999
# 2    2024-04-27  3.999
# 3    2024-04-26  3.999
# 4    2024-04-25  3.999
# ...         ...    ...
# 1091 2021-05-04  3.999
# 1092 2021-05-03  3.999
# 1093 2021-05-02  3.999
# 1094 2021-05-01  3.999
# 1095 2021-04-30  3.999
#
# [1095 rows x 2 columns]
# <ipython-input-49-e2e1d185bab0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# <ipython-input-49-e2e1d185bab0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.info()

# %%
# Plotar o gráfico de histórico de preços
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price'], marker='o', linestyle='-')
plt.title('Histórico de Preços')
plt.xlabel('Data')
plt.ylabel('Preço')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
